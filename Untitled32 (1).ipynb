# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %%
Missing_Values = ["?"," ","_","NaN","nan"]

home = pd.read_csv('Nashville_housing_data_2013_2016.csv', na_values= Missing_Values)
home.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         Parcel ID           Land Use  \
# 0           0             0  105 03 0D 008.00  RESIDENTIAL CONDO
# 1           1             1   105 11 0 080.00      SINGLE FAMILY
# 2           2             2   118 03 0 130.00      SINGLE FAMILY
# 3           3             3   119 01 0 479.00      SINGLE FAMILY
# 4           4             4   119 05 0 186.00      SINGLE FAMILY
#
#     Property Address Suite/ Condo   # Property City   Sale Date  Sale Price  \
# 0    1208  3RD AVE S                8     NASHVILLE  2013-01-24      132000
# 1   1802  STEWART PL              NaN     NASHVILLE  2013-01-11      191500
# 2  2761  ROSEDALE PL              NaN     NASHVILLE  2013-01-18      202000
# 3  224  PEACHTREE ST              NaN     NASHVILLE  2013-01-18       32000
# 4      316  LUTIE ST              NaN     NASHVILLE  2013-01-23      102000
#
#     Legal Reference  ... Building Value Total Value Finished Area  \
# ...

# %%
home.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Parcel ID', 'Land Use',
#        'Property Address', 'Suite/ Condo   #', 'Property City', 'Sale Date',
#        'Sale Price', 'Legal Reference', 'Sold As Vacant',
#        'Multiple Parcels Involved in Sale', 'Owner Name', 'Address', 'City',
#        'State', 'Acreage', 'Tax District', 'Neighborhood', 'image',
#        'Land Value', 'Building Value', 'Total Value', 'Finished Area',
#        'Foundation Type', 'Year Built', 'Exterior Wall', 'Grade', 'Bedrooms',
#        'Full Bath', 'Half Bath'],
#       dtype='object')

# %%
home= home[['Land Use', 'Sale Price', 'Multiple Parcels Involved in Sale', 'Acreage', 'Neighborhood',
       'Land Value', 'Building Value', 'Total Value', 'Finished Area', 'Year Built', 
        'Bedrooms', 'Full Bath', 'Half Bath']]
home
# Out:
#                 Land Use  Sale Price Multiple Parcels Involved in Sale  \
# 0      RESIDENTIAL CONDO      132000                                No
# 1          SINGLE FAMILY      191500                                No
# 2          SINGLE FAMILY      202000                                No
# 3          SINGLE FAMILY       32000                                No
# 4          SINGLE FAMILY      102000                                No
# ...                  ...         ...                               ...
# 56631  RESIDENTIAL CONDO      210000                                No
# 56632  RESIDENTIAL CONDO      338000                                No
# 56633  RESIDENTIAL CONDO      742000                                No
# 56634  RESIDENTIAL CONDO      320000                                No
# 56635  RESIDENTIAL CONDO      330000                                No
#
#        Acreage  Neighborhood  Land Value  Building Value  Total Value  \
# ...

# %%
home.isnull().sum()
# Out:
# Land Use                                 0
# Sale Price                               0
# Multiple Parcels Involved in Sale        0
# Acreage                              30619
# Neighborhood                         30619
# Land Value                           30619
# Building Value                       30619
# Total Value                          30619
# Finished Area                        32470
# Year Built                           32471
# Bedrooms                             32477
# Full Bath                            32359
# Half Bath                            32490
# dtype: int64

# %%
home = home.dropna(thresh=len(home.columns)-5)
home= home.dropna(subset=['Half Bath'])
home.isnull().sum()
# Out:
# Land Use                               0
# Sale Price                             0
# Multiple Parcels Involved in Sale      0
# Acreage                                0
# Neighborhood                           0
# Land Value                             0
# Building Value                         0
# Total Value                            0
# Finished Area                        116
# Year Built                           115
# Bedrooms                             119
# Full Bath                              0
# Half Bath                              0
# dtype: int64

# %%
sns.boxplot(data=home, x="Finished Area").set(title='Finished Area Boxplot Distribution')
print("Median: ",home["Finished Area"].median())
print("Mean: ",home["Finished Area"].mean())
# Out:
# Median:  1630.0
# Mean:  1926.9636708905564

# %%
home['Bedrooms'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
home['Year Built'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.hist(home['Sale Price'])
# Out:
# (array([2.3697e+04, 3.9900e+02, 3.6000e+01, 9.0000e+00, 2.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([1.000000e+02, 1.235090e+06, 2.470080e+06, 3.705070e+06,
#         4.940060e+06, 6.175050e+06, 7.410040e+06, 8.645030e+06,
#         9.880020e+06, 1.111501e+07, 1.235000e+07]),
#  <BarContainer object of 10 artists>)

# %%
home["Finished Area"] = home["Finished Area"].fillna(home["Finished Area"].mean())
home.isnull().sum()
# Out:
# Land Use                               0
# Sale Price                             0
# Multiple Parcels Involved in Sale      0
# Acreage                                0
# Neighborhood                           0
# Land Value                             0
# Building Value                         0
# Total Value                            0
# Finished Area                          0
# Year Built                           115
# Bedrooms                             119
# Full Bath                              0
# Half Bath                              0
# dtype: int64

# %%
sns.boxplot(data=home, x="Year Built").set(title='Boxplot Distribution of Built Year')
print("Median: ",home["Year Built"].median())
print("Mean: ",home["Year Built"].mean())
# Out:
# Median:  1960.0
# Mean:  1963.6758353793018

# %%
home["Year Built"] = home["Year Built"].fillna(home["Year Built"].median())
home.isnull().sum()
# Out:
# Land Use                               0
# Sale Price                             0
# Multiple Parcels Involved in Sale      0
# Acreage                                0
# Neighborhood                           0
# Land Value                             0
# Building Value                         0
# Total Value                            0
# Finished Area                          0
# Year Built                             0
# Bedrooms                             119
# Full Bath                              0
# Half Bath                              0
# dtype: int64

# %%
sns.boxplot(data=home, x="Bedrooms").set(title='Boxplot Distribution of Bedrooms')
print("Median: ",home["Bedrooms"].median())
print("Mean: ",home["Bedrooms"].mean())
# Out:
# Median:  3.0
# Mean:  3.0894826653348315

# %%
home["Bedrooms"] = home["Bedrooms"].fillna(home["Bedrooms"].median())
home.isnull().sum()
# Out:
# Land Use                             0
# Sale Price                           0
# Multiple Parcels Involved in Sale    0
# Acreage                              0
# Neighborhood                         0
# Land Value                           0
# Building Value                       0
# Total Value                          0
# Finished Area                        0
# Year Built                           0
# Bedrooms                             0
# Full Bath                            0
# Half Bath                            0
# dtype: int64

# %%
sns.jointplot(x='Bedrooms',y='Sale Price',data=home,kind='scatter',size=4)
# Out:
# C:\Users\Prajakta Sable\anaconda3\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
print(len(home['Land Use'].unique()))
home['Land Use'].unique()
# Out:
# 26
# array(['SINGLE FAMILY', 'VACANT RES LAND', 'DUPLEX', 'ZERO LOT LINE',
#        'TRIPLEX', 'RESIDENTIAL COMBO/MISC', 'CHURCH', 'QUADPLEX',
#        'STRIP SHOPPING CENTER', 'DORMITORY/BOARDING HOUSE', 'PARSONAGE',
#        'SPLIT CLASS', 'GREENBELT', 'MOBILE HOME',
#        'OFFICE BLDG (ONE OR TWO STORIES)', 'VACANT RESIDENTIAL LAND',
#        'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'CLUB/UNION HALL/LODGE', 'LIGHT MANUFACTURING',
#        'ONE STORY GENERAL RETAIL STORE', 'DAY CARE CENTER',
#        'APARTMENT: LOW RISE (BUILT SINCE 1960)',
#        'TERMINAL/DISTRIBUTION WAREHOUSE', 'NON-PROFIT CHARITABLE SERVICE',
#        'GREENBELT/RES\r\nGRRENBELT/RES'], dtype=object)

# %%
home = home.replace(['SINGLE FAMILY', 'VACANT RES LAND', 'DUPLEX', 'ZERO LOT LINE',
       'TRIPLEX', 'RESIDENTIAL COMBO/MISC', 'QUADPLEX','DORMITORY/BOARDING HOUSE', 
        'SPLIT CLASS', 'MOBILE HOME', 'VACANT RESIDENTIAL LAND',
         'APARTMENT: LOW RISE (BUILT SINCE 1960)'],'Residential')

home = home.replace(['CHURCH', 'STRIP SHOPPING CENTER','PARSONAGE', 'OFFICE BLDG (ONE OR TWO STORIES)',
                'CONVENIENCE MARKET WITHOUT GAS', 'CLUB/UNION HALL/LODGE', 'LIGHT MANUFACTURING',
                'ONE STORY GENERAL RETAIL STORE', 'DAY CARE CENTER', 'TERMINAL/DISTRIBUTION WAREHOUSE', 
                 'NON-PROFIT CHARITABLE SERVICE',],'Commercial')

home = home.replace(['FOREST', 'GREENBELT/RES\r\nGRRENBELT/RES','GREENBELT', ],'Green_Zone')
home['Land Use'].unique()
# Out:
# array(['Residential', 'Commercial', 'Green_Zone'], dtype=object)

# %%
home = pd.get_dummies(home)
home.head()
# Out:
#    Sale Price  Acreage  Neighborhood  Land Value  Building Value  Total Value  \
# 1      191500     0.17        3127.0     32000.0        134400.0     168300.0
# 2      202000     0.11        9126.0     34000.0        157800.0     191800.0
# 3       32000     0.17        3130.0     25000.0        243700.0     268700.0
# 4      102000     0.34        3130.0     25000.0        138100.0     164800.0
# 5       93736     0.17        3130.0     25000.0         86100.0     113300.0
#
#    Finished Area  Year Built  Bedrooms  Full Bath  Half Bath  \
# 1     1149.00000      1941.0       2.0        1.0        0.0
# 2     2090.82495      2000.0       3.0        2.0        1.0
# 3     2145.60001      1948.0       4.0        2.0        0.0
# 4     1969.00000      1910.0       2.0        1.0        0.0
# 5     1037.00000      1945.0       2.0        1.0        0.0
#
#    Land Use_Commercial  Land Use_Green_Zone  Land Use_Residential  \
# ...

# %%
cor = home.corr()
plt.figure(figsize=(10 , 12))
heatmap = sns.heatmap(cor, vmin=-1, vmax=1, annot=True, cmap='YlGnBu')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %%
X = home.drop(['Sale Price'], axis=1)
X
# Out:
#        Acreage  Neighborhood  Land Value  Building Value  Total Value  \
# 1         0.17        3127.0     32000.0        134400.0     168300.0
# 2         0.11        9126.0     34000.0        157800.0     191800.0
# 3         0.17        3130.0     25000.0        243700.0     268700.0
# 4         0.34        3130.0     25000.0        138100.0     164800.0
# 5         0.17        3130.0     25000.0         86100.0     113300.0
# ...        ...           ...         ...             ...          ...
# 56605     0.27        6328.0     25000.0        142400.0     167400.0
# 56607     0.23        6328.0     25000.0        159300.0     184300.0
# 56614     0.15         126.0     40000.0        204100.0     256000.0
# 56615     0.19         126.0     40000.0        295900.0     351600.0
# 56616     0.20         126.0     40000.0          5100.0      46000.0
#
#        Finished Area  Year Built  Bedrooms  Full Bath  Half Bath  \
# ...

# %%
Y = home["Sale Price"]
Y
# Out:
# 1        191500
# 2        202000
# 3         32000
# 4        102000
# 5         93736
#           ...
# 56605    214000
# 56607    236000
# 56614    466000
# 56615    685000
# 56616    280000
# Name: Sale Price, Length: 24146, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test,Y_Train, Y_Test = train_test_split(X, Y, test_size=0.2)
print("Train:", X_Train.shape, Y_Train.shape)
print("Test:", X_Test.shape, Y_Test.shape)
# Out:
# Train: (19316, 15) (19316,)
# Test: (4830, 15) (4830,)

# %%
from sklearn import linear_model
lm1 = linear_model.LinearRegression().fit(X_Train, Y_Train)
Y_Pred = lm1.predict(X_Test)

# %%
print('Intercept: ', lm1.intercept_)
print('Coefficients: ', lm1.coef_)
# Out:
# Intercept:  1533104.0804458372
# Coefficients:  [ 2.73386210e+02 -5.30586206e+00 -1.66691409e+00 -2.48916722e+00
#   3.02928083e+00  1.64449425e+01 -6.40923662e+02  1.25452856e+03
#   1.10116719e+04  9.50354617e+03 -9.26320365e+04  2.37002800e+05
#  -1.44370764e+05 -9.05416637e+04  9.05416637e+04]

# %%
X_Train
# Out:
#        Acreage  Neighborhood  Land Value  Building Value  Total Value  \
# 50712     0.45        7328.0     38700.0        112900.0     151600.0
# 54845     0.49        2726.0     43900.0        110500.0     154400.0
# 40678     1.01        6931.0     30000.0        100000.0     130000.0
# 45875     0.35        6027.0     27500.0        103800.0     131300.0
# 23930     0.29        9327.0     22000.0         91000.0     114500.0
# ...        ...           ...         ...             ...          ...
# 3071      0.45        9528.0    203500.0        682900.0     886400.0
# 12516     0.43        3626.0     29900.0        173400.0     203300.0
# 35047     0.16        3628.0     26000.0         81700.0     107700.0
# 21313     0.69        6829.0     25000.0        104800.0     131200.0
# 36274     0.23        6735.0     40000.0        106700.0     146700.0
#
#        Finished Area  Year Built  Bedrooms  Full Bath  Half Bath  \
# ...

# %%
from sklearn.metrics import mean_squared_error
print('Mean Squared Error(MSE):%.2f' % mean_squared_error(Y_Test,Y_Pred))

from sklearn.metrics import r2_score
print('r_sqrd value:%.3f' % r2_score(Y_Test,Y_Pred))
# Out:
# Mean Squared Error(MSE):22086835940.69
# r_sqrd value:0.731

# %%
abs_co = abs(lm1.coef_)
abs_co
# Out:
# array([2.73386210e+02, 5.30586206e+00, 1.66691409e+00, 2.48916722e+00,
#        3.02928083e+00, 1.64449425e+01, 6.40923662e+02, 1.25452856e+03,
#        1.10116719e+04, 9.50354617e+03, 9.26320365e+04, 2.37002800e+05,
#        1.44370764e+05, 9.05416637e+04, 9.05416637e+04])

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import explained_variance_score
from sklearn.metrics import confusion_matrix

# %%
from sklearn import metrics
from sklearn import tree

DT1 = tree.DecisionTreeClassifier().fit(X_Train, Y_Train)
Y_Pred = DT1.predict(X_Test)
print("Accuracy:",metrics.accuracy_score(Y_Test, Y_Pred))
# Out:
# Accuracy: 0.02339544513457557

# %%
import sklearn
from sklearn.metrics import classification_report
#sklearn.metrics.classification_report
report = classification_report(Y_Pred, Y_Test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         1000       0.00      0.00      0.00         0
#         5000       0.00      0.00      0.00         0
#         7250       0.00      0.00      0.00         1
#         7500       0.00      0.00      0.00         2
#         8000       0.00      0.00      0.00         0
#         8500       0.00      0.00      0.00         0
#         9000       0.00      0.00      0.00         3
#         9250       0.00      0.00      0.00         0
#        10000       0.00      0.00      0.00         5
#        11000       0.00      0.00      0.00         2
#        11347       0.00      0.00      0.00         0
#        11500       0.00      0.00      0.00         0
#        12000       0.00      0.00      0.00         3
#        14000       0.00      0.00      0.00         2
#        14500       0.00      0.00      0.00         0
#        15000       0.00      0.00      0.00         4
# ...

# %%
#dt
tr_regressor = DecisionTreeRegressor(random_state=0)
tr_regressor.fit(X_Train,Y_Train)
tr_regressor.score(X_Test,Y_Test)
pred_tr = tr_regressor.predict(X_Test)
decision_score=tr_regressor.score(X_Test,Y_Test)
expl_tr = explained_variance_score(pred_tr,Y_Test)

# %%
expl_tr
# Out:
# 0.6203607109239211

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees


print('Training Features Shape:', X_Train.shape)
print('Training Labels Shape:', X_Test.shape)
print('Testing Features Shape:', Y_Train.shape)
print('Testing Labels Shape:', Y_Test.shape)
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_Train, Y_Train);
# Out:
# Training Features Shape: (19316, 15)
# Training Labels Shape: (4830, 15)
# Testing Features Shape: (19316,)
# Testing Labels Shape: (4830,)

# %%
mlr = LinearRegression()
mlr.fit(X_Train,Y_Train)
mlr_score = mlr.score(X_Test,Y_Train)
pred_mlr = mlr.predict(X_Test)
expl_mlr = explained_variance_score(pred_mlr,Y_Test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3200ab02e86b> in <module>
#       1 mlr = LinearRegression()
#       2 mlr.fit(X_Train,Y_Train)
# ----> 3 mlr_score = mlr.score(X_Test,Y_Train)
#       4 pred_mlr = mlr.predict(X_Test)
#       5 expl_mlr = explained_variance_score(pred_mlr,Y_Test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     552         from .metrics import r2_score
#     553         y_pred = self.predict(X)
# --> 554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#     556     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
# ...

# %%
rf_regressor = RandomForestRegressor(n_estimators=28,random_state=0)
rf_regressor.fit(X_Train,Y_Train)
rf_regressor.score(X_Test,Y_Test)
rf_pred =rf_regressor.predict(X_Test)
rf_score=rf_regressor.score(X_Test,Y_Test)
expl_rf = explained_variance_score(rf_pred,Y_Test)

# %%
rf_regressor
rf_score
# Out:
# 0.7091275812346309

# %%
from sklearn.tree import DecisionTreeRegressor
print("Multiple Linear Regression Model Score is ",round(mlr.score(X_Test,Y_Test)*100))
print("Decision tree  Regression Model Score is ",round(tr_regressor.score(X_Test,Y_Test)*100))
print("Random Forest Regression Model Score is ",round(rf_regressor.score(X_Test,Y_Test)*100))

#Let's have a tabular pandas data frame, for a clear comparison

models_score =pd.DataFrame({'Model':['Multiple Linear Regression','Decision Tree','Random forest Regression'],
                            'Score':[mlr_score,decision_score,rf_score],
                            'Explained Variance Score':[expl_mlr,expl_tr,expl_rf]
                           })
models_score.sort_values(by='Score',ascending=False)
# Out:
# Multiple Linear Regression Model Score is  73
# Decision tree  Regression Model Score is  55
# Random Forest Regression Model Score is  71
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-91d4a1ffc750> in <module>
#       7
#       8 models_score =pd.DataFrame({'Model':['Multiple Linear Regression','Decision Tree','Random forest Regression'],
# ----> 9                             'Score':[mlr_score,decision_score,rf_score],
#      10                             'Explained Variance Score':[expl_mlr,expl_tr,expl_rf]
#      11                            })
#
# NameError: name 'mlr_score' is not defined

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import GradientBoostingClassifier

grid = {

    'learning_rate':[0.01,0.05,0.1],

    'n_estimators':np.arange(100,500,100),

}


gb = GradientBoostingClassifier()

gb_cv = GridSearchCV(gb, grid, cv = 4)

gb_cv.fit(X_Train,Y_Train)

print("Best Parameters:",gb_cv.best_params_)

print("Train Score:",gb_cv.best_score_)

print("Test Score:",gb_cv.score(X_Test,X_Test))
